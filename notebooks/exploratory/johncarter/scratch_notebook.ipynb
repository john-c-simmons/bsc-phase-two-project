# %%
import pandas as pd
import seaborn as sns
import matplotlib as plt
from geopy.geocoders import Nominatim
import numpy as np
df = pd.read_csv('../../../data/kc_house_data.csv')

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df[df.sqft_basement == 0.0]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# ...

# %%
df.yr_renovated.isna()
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 21592    False
# 21593    False
# 21594    False
# 21595    False
# 21596    False
# Name: yr_renovated, Length: 21597, dtype: bool

# %%
df.corr().price
# Out:
# id              -0.016772
# price            1.000000
# bedrooms         0.308787
# bathrooms        0.525906
# sqft_living      0.701917
# sqft_lot         0.089876
# floors           0.256804
# waterfront       0.276295
# view             0.395734
# condition        0.036056
# grade            0.667951
# sqft_above       0.605368
# yr_built         0.053953
# yr_renovated     0.129599
# zipcode         -0.053402
# lat              0.306692
# long             0.022036
# sqft_living15    0.585241
# sqft_lot15       0.082845
# Name: price, dtype: float64

# %%
gradeplot = sns.lmplot(x='grade', y='price', data=df)
gradeplot.set(xlim=(2, 14))

# %%
mapplot = sns.scatterplot(x='long', y='lat', data=df)

# %%
df.grade.unique()
# Out:
# array([ 7,  6,  8, 11,  9,  5, 10, 12,  4,  3, 13])

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.001150   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.308787   0.525906     0.701917  0.089876
# bedrooms       0.001150  0.308787  1.000000   0.514508     0.578212  0.032471
# bathrooms      0.005162  0.525906  0.514508   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.578212   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.032471   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.177944   0.502582     0.353953 -0.004814
# waterfront    -0.004176  0.276295 -0.002386   0.067282     0.110230  0.023143
# view           0.011592  0.395734  0.078523   0.186451     0.282532  0.075298
# condition     -0.023803  0.036056  0.026496  -0.126479    -0.059445 -0.008830
# grade          0.008188  0.667951  0.356563   0.665838     0.762779  0.114731
# ...

# %%
df[df.bedrooms == 0]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.bedrooms[15856] = 3
# Out:
# <ipython-input-66-e3de06c360dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.bedrooms[15856] = 3

# %%
df.loc[ 15856, :]
# Out:
# id               2402100895
# date              6/25/2014
# price                640000
# bedrooms                  3
# bathrooms              1.75
# sqft_living            1620
# sqft_lot               6000
# floors                    1
# waterfront                0
# view                      0
# condition                 5
# grade                     7
# sqft_above             1040
# sqft_basement         580.0
# yr_built               1947
# yr_renovated              0
# zipcode               98103
# lat                 47.6878
# long               -122.331
# sqft_living15          1330
# sqft_lot15             4700
# Name: 15856, dtype: object

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.head(20)
# Out:
#             id        date      price  bedrooms  bathrooms  sqft_living  \
# 0   7129300520  10/13/2014   221900.0         3       1.00         1180
# 1   6414100192   12/9/2014   538000.0         3       2.25         2570
# 2   5631500400   2/25/2015   180000.0         2       1.00          770
# 3   2487200875   12/9/2014   604000.0         4       3.00         1960
# 4   1954400510   2/18/2015   510000.0         3       2.00         1680
# 5   7237550310   5/12/2014  1230000.0         4       4.50         5420
# 6   1321400060   6/27/2014   257500.0         3       2.25         1715
# 7   2008000270   1/15/2015   291850.0         3       1.50         1060
# 8   2414600126   4/15/2015   229500.0         3       1.00         1780
# 9   3793500160   3/12/2015   323000.0         3       2.50         1890
# 10  1736800520    4/3/2015   662500.0         3       2.50         3560
# 11  9212900260   5/27/2014   468000.0         2       1.00         1160
# ...

# %%
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
geolocator = Nominatim(user_agent="johncarter")
lat = df.lat[0]
long=df.long[0]

def address(lat, long):
    
    location = geolocator.reverse(f"{lat}, {long}")
    try:
        house_number = location.raw['address']['house_number']
    except:
        house_number = np.nan
    
    try:
        road = location.raw['address']['road']
    except:
        road = np.nan
        
    return house_number, road


house_numbers = []
roads = []

for idx in df.index:
    
    lat = df.lat[idx]
    lon = df.long[idx]

    house, road = address(lat, lon)

    house_numbers.append(house)
    roads.append(road)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-6fa843a26cd7> in <module>
#      27     lon = df.long[idx]
#      28
# ---> 29     house, road = address(lat, lon)
#      30
#      31     house_numbers.append(house)
#
# <ipython-input-75-6fa843a26cd7> in address(lat, long)
#       5 def address(lat, long):
#       6
# ----> 7     location = geolocator.reverse(f"{lat}, {long}")
#       8     try:
#       9         house_number = location.raw['address']['house_number']
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/geopy/geocoders/nominatim.py in reverse(self, query, exactly_one, timeout, language, addressdetails, zoom)
#     360         logger.debug("%s.reverse: %s", self.__class__.__name__, url)
#     361         callback = partial(self._parse_json, exactly_one=exactly_one)
# ...

# %%
 df.long[0]

# %%
from tkinter import *
window = Tk()
label = Label(text="Python rocks!")
label.pack()

window.mainloop()
