# %%
import pandas as pd
import seaborn as sns
df = pd.read_csv('../../../data/kc_house_data.csv')

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df[df.sqft_basement == 0.0]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.159700e+04  21597.000000  19221.000000  21534.000000  21597.000000
# mean   1.509941e+04      1.494096      0.007596      0.233863      3.409825
# ...

# %%
df.yr_renovated.isna()
# Out:
# 0        False
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 21592    False
# 21593    False
# 21594    False
# 21595    False
# 21596    False
# Name: yr_renovated, Length: 21597, dtype: bool

# %%
df.corr().price
# Out:
# id              -0.016772
# price            1.000000
# bedrooms         0.308787
# bathrooms        0.525906
# sqft_living      0.701917
# sqft_lot         0.089876
# floors           0.256804
# waterfront       0.276295
# view             0.395734
# condition        0.036056
# grade            0.667951
# sqft_above       0.605368
# yr_built         0.053953
# yr_renovated     0.129599
# zipcode         -0.053402
# lat              0.306692
# long             0.022036
# sqft_living15    0.585241
# sqft_lot15       0.082845
# Name: price, dtype: float64

# %%
gradeplot = sns.lmplot(x='price', y='grade', data=df)
gradeplot.set(ylim=(2, 14))

# %%
df.grade.unique()
# Out:
# array([ 7,  6,  8, 11,  9,  5, 10, 12,  4,  3, 13])

# %%
df.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016772  0.002342   0.005162    -0.012241 -0.131911
# price         -0.016772  1.000000  0.315954   0.525906     0.701917  0.089876
# bedrooms       0.002342  0.315954  1.000000   0.527874     0.593182  0.033606
# bathrooms      0.005162  0.525906  0.527874   1.000000     0.755758  0.088373
# sqft_living   -0.012241  0.701917  0.593182   0.755758     1.000000  0.173453
# sqft_lot      -0.131911  0.089876  0.033606   0.088373     0.173453  1.000000
# floors         0.018608  0.256804  0.183721   0.502582     0.353953 -0.004814
# waterfront    -0.004176  0.276295 -0.002301   0.067282     0.110230  0.023143
# view           0.011592  0.395734  0.080928   0.186451     0.282532  0.075298
# condition     -0.023803  0.036056  0.023390  -0.126479    -0.059445 -0.008830
# grade          0.008188  0.667951  0.366181   0.665838     0.762779  0.114731
# ...

# %%
df[df.bedrooms == 0]
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
df.bedrooms[15856] = 3
# Out:
# <ipython-input-99-e3de06c360dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.bedrooms[15856] = 3

# %%
df.loc[ 15856, :]
# Out:
# id               2402100895
# date              6/25/2014
# price                640000
# bedrooms                  3
# bathrooms              1.75
# sqft_living            1620
# sqft_lot               6000
# floors                    1
# waterfront                0
# view                      0
# condition                 5
# grade                     7
# sqft_above             1040
# sqft_basement         580.0
# yr_built               1947
# yr_renovated              0
# zipcode               98103
# lat                 47.6878
# long               -122.331
# sqft_living15          1330
# sqft_lot15             4700
# Name: 15856, dtype: object

# %%
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]
